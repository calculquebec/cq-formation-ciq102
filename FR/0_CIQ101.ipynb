# %% [markdown]
# ![banniere.png](attachment:acedbb86-8a87-43b5-8fc9-f382bf1df434.png)

# %%
import pennylane as qml
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Dans l’atelier CIQ 101 : Théorie du calcul quantique, vous avez programmé un simulateur quantique à un qubit en traduisant directement les lois de la mécanique quantique à l’aide d’opérations d’algèbre linéaire et de la librairie NumPy.
#
# Pour rappel, les étapes principales étaient les suivantes :
#
# * Initialiser le qubit dans l’état de base $\lvert 0 \rangle$.
#
# * Appliquer une porte de Hadamard afin de créer une superposition égale :
# $\lvert \psi \rangle = \frac{1}{\sqrt{2}}(\lvert 0 \rangle + \lvert 1 \rangle)$.
#
# * Simuler une mesure probabiliste en effectuant 1000 échantillons (ou shots), selon la distribution de probabilité définie par l’état en superposition.

# %% [markdown]
# ![Bloch sphere.png](attachment:2efdd9f3-1f6e-4dd3-a114-f4ea34278409.png)

# %% [markdown]
# Dans cet atelier, nous verrons comment faire abstraction de l’algèbre linéaire en utilisant le simulateur quantique PennyLane. Toutes les opérations seront représentées à l’aide de circuits quantiques. Par exemple, pour le cas présenté ci-haut, le circuit quantique correspond à l’image ci-dessous.

# %% [markdown]
# ![download-2.png](attachment:d49f20da-3008-40a7-9b8d-854468f173fc.png)

# %% [markdown]
# [PennyLane](https://pennylane.ai/) est une plateforme logicielle à code source ouvert pour le calcul quantique différentiable, développée par Xanadu.
